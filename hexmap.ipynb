# %%
from game import game
from player import Player

# %%
board = game.create_board(seed=1111)
kai   = game.create_player(Player('kai','red'))
liam  = game.create_player(Player('liam','blue'))

game.display(board)

# %%
game.next_phase()
# Out:
# initial placement

# %%
kai.place_village(board[4,0])
liam.place_village(board[6,1])
game.display(board)

# %%
kai.place_fort(board[3,0])
liam.place_fort(board[6,0])
game.display(board)

# %%
game.next_phase()
# Out:
# resource allocation

# %%
game.resources()
# Out:
# Player kai was allocated 1 sheep from village at (4, 0)
# Player liam was allocated 1 grain from village at (6, 1)

# %%
game.next_phase()
# Out:
# trading

# %%
game.trading(kai.trade('sheep',1),liam.trade('grain',1))
# Out:
# Player kai and Player liam traded

# %%
game.next_phase()
# Out:
# propose movement

# %%
#no armies to move

# %%
game.next_phase()
# Out:
# movement execution

# %%
game.resolve()

# %%
game.next_phase()
# Out:
# building

# %%
kai.build_army(board[4,0])
game.display(board)

# %%
game.next_phase()
# Out:
# resource allocation

# %%
game.resources()
# Out:
# Player kai was allocated 1 sheep from village at (4, 0)
# Player liam was allocated 1 grain from village at (6, 1)

# %%
game.next_phase()
# Out:
# trading

# %%
game.trading(kai.trade('sheep',1),liam.trade('grain',1))
# Out:
# Player kai and Player liam traded

# %%
game.next_phase()
# Out:
# propose movement

# %%
kai.army(board[4,0]).move(board[5,0])
kai.army(board[4,0]).support(kai.village(board[3,0]))

# %%
game.next_phase()
# Out:
# movement execution

# %%
game.resolve()
game.display(board)
# Out:
# Resolving kai move to (5, 0)
